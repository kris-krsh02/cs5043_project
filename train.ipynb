# %%
# !git clone https://github.com/kris-krsh02/cs5043_project.git
# %cd cs5043_project

# %%
# !pip install -r requirements.txt

# %%
import sys
sys.path.append('/content/cs5043_project')

# %%
from run_experiments import run_experiment

# %%
import torch
print(torch.cuda.is_available())

# %%
run_experiment('base', max_batches=1)

# %%
run_experiment('prompt', max_batches=1)

# %%
run_experiment('prompt_summary', max_batches=1)
